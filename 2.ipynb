# %%
import pandas as pd
import numpy as np

# %%
import pandas as pd

data1 = pd.read_csv("StudentsPerformance.csv")
print(data1.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
data1["parental level of education"].unique()
# Out:
# <StringArray>
# [ 'bachelor's degree',       'some college',    'master's degree',
#  'associate's degree',        'high school',   'some high school']
# Length: 6, dtype: str

# %%
print(data1.columns)
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %%
data1.groupby('parental level of education')

# %%
data1.rename(columns={'race/ethnicity': 'groups'}, inplace=True)
data1
# Out:
#      gender   groups parental level of education         lunch  \
# 0    female  group B           bachelor's degree      standard
# 1    female  group C                some college      standard
# 2    female  group B             master's degree      standard
# 3      male  group A          associate's degree  free/reduced
# 4      male  group C                some college      standard
# ..      ...      ...                         ...           ...
# 995  female  group E             master's degree      standard
# 996    male  group C                 high school  free/reduced
# 997  female  group C                 high school  free/reduced
# 998  female  group D                some college      standard
# 999  female  group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 0                      none          72             72             74
# ...

# %%
data1.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   str
#  1   race and ethnicity           1000 non-null   str
#  2   parental level of education  1000 non-null   str
#  3   lunch                        1000 non-null   str
#  4   test preparation course      1000 non-null   str
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), str(5)
# memory usage: 62.6 KB

# %%
data1.rename(columns={'race/ethnicity':'groups'},inplace=True)

# %%
import pandas as pd

data1 = pd.read_csv("StudentsPerformance.csv")
print(data1.head())
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
groups=data1.groupby("groups")

# %%
groups["writing score"].mean(numeric_only=True).sort_values().head(1)
# Out:
# groups
# group A    62.674157
# Name: writing score, dtype: float64

# %%
groups["math score"].sum(numeric_only=True).sort_values()\
.tail()
# Out:
# groups
# group A     5485
# group E    10335
# group B    12056
# group D    17649
# group C    20564
# Name: math score, dtype: int64

# %%
data1.columns
# Out:
# Index(['gender', 'groups', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %%
print(data1.columns)
# Out:
# Index(['gender', 'groups', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='str')

# %%
groups = data1.groupby('test preparation course')
groups['writing score'].mean()
# Out:
# test preparation course
# completed    74.418994
# none         64.504673
# Name: writing score, dtype: float64

# %%
gp=data1.groupby('parental level of education')
gp['reading score'].sum(numeric_only=True).sort_values().tail(1)
# Out:
# parental level of education
# associate's degree    15746
# Name: reading score, dtype: int64

# %%
data1.groupby('parental level of education').groups
# Out:
# {'associate's degree': [3, 5, 10, 11, 19, 35, 36, 38, 39, 40, 41, 42, 44, 45, 46, 48, 51, 56, 57, 62, 63, 68, 69, 72, 75, 80, 83, 87, 93, 95, 102, 107, 108, 110, 112, 121, 138, 147, 149, 152, 158, 159, 160, 173, 177, 183, 185, 190, 195, 200, 202, 203, 213, 216, 221, 224, 231, 235, 239, 245, 246, 256, 257, 268, 272, 285, 286, 290, 295, 297, 299, 302, 303, 304, 308, 310, 313, 317, 319, 328, 331, 332, 333, 337, 343, 349, 353, 356, 375, 380, 381, 387, 393, 397, 406, 407, 409, 412, 417, 420, ...], 'bachelor's degree': [0, 24, 27, 60, 77, 90, 99, 101, 114, 116, 117, 120, 129, 134, 135, 148, 151, 153, 165, 174, 189, 199, 206, 232, 234, 236, 241, 266, 270, 275, 279, 282, 288, 293, 311, 312, 314, 318, 334, 347, 350, 355, 365, 367, 374, 379, 386, 414, 416, 426, 455, 456, 458, 460, 464, 475, 476, 493, 507, 509, 522, 528, 535, 538, 551, 562, 564, 566, 569, 571, 582, 587, 592, 594, 595, 612, 616, 617, 621, 624, 632, 645, 667, 692, 697, 700, 702, 705, 740, 748, 757, 771, 773, 784, 809, 816, 817, 8
# ...

# %%
data1.groupby('gender').ngroups
# Out:
# 2
